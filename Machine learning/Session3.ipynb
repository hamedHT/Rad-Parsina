# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
years = [1960,1970,1980,1990,2000,2010,2020]
iranpop = [21,28,38,56,66,74,80]

# %%
# plt.figure(figsize = (5,6), dpi=100)
# plt.xlabel('years')
# plt.ylabel('iranpop')
# plt.yticks([21,28,38,56,66,74,80],['21m','28m','38m','56m','66m','74m','80'])


plt.plot(years, iranpop)
plt.show()

# %%
popsize= np.array([21,28,38,56,66,740])
test = [444,8888,9999,111,222,5614]
colors=['violet','green','orange','tomato','blue','pink']
plt.scatter(np.arange(6), test,s=popsize,c=colors)
# plt.scatter(years, iranpop)
# plt.text(1970,30,'revolution')
plt.show()

# %%
plt.hist(iranpop,bins = "auto")
plt.show()

# %%
plt.pie(iranpop,labels = years)
plt.title("iran population")
plt.show()
